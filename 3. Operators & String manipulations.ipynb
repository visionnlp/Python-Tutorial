# %% [markdown]
# #### 1. Numbers
# - 1.1 Conversions of types
#
# #### 2. Operators
# - 2.1 Arithmetic operators
# - 2.2 Logical operators
#
# #### 3. String
# - 3.1 Different ways of defining strings
# - 3.2 Operations on string
# - 3.3 Slicing and indexing
# - 3.4 Place holder

# %% [markdown]
# #### 1.1 Conversions of types

# %%
# from int to float
a = 3
a
# Out:
# 3

# %%
float(a) # built_in_fun(variable_name)
# Out:
# 3.0

# %%
# from float to int
b = 3.3
print(type(b))

c = int(b)
type(c)
# Out:
# <class 'float'>
# int

# %%
# from int to string
f = str(a)
f
# Out:
# '3'

# %%
type(f)

# %%
# but we can't convert string into any type of numbers  (int or float)
g = 'Mayur'
h = int(g)
print(h)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 # but we can't convert string into any type of numbers  (int or float)
#       2 g = 'Mayur'
# ----> 3 h = int(g)
#       4 print(h)
#
# ValueError: invalid literal for int() with base 10: 'Mayur'

# %% [markdown]
# #### 2.1 Arithmetic operators
#
# ![arithmatic.PNG](attachment:arithmatic.PNG)

# %% [markdown]
# ##### Basically  there are five aithmetic operators
# 1. ' + ' : for addition
# 2. ' - ' : for substraction
# 3. ' * ' : for multiplication
# 4. ' / ' : for real division
# 5. ' % ' : for integer division

# %% [markdown]
# #### 2.1. a) Addition of numbers
#
# - we can add any type of numbers also we can add multiple numbers at a time

# %%
4-7
# Out:
# -3

# %%
a=8 # int
b=3
c=3.7 # float
d=5.3

# %%
# sum of two whole numbers
add = a+b
add
# Out:
# 11

# %%
# sum of of two real numbers 
c+d
# Out:
# 9.0

# %%
# sum of one real and one whole number 
a+c
# Out:
# 11.7

# %%
# sum of multiple numbers 
a+b+c+d
# Out:
# 20.0

# %% [markdown]
# #### 2.1 . b) Subtraction of numbers

# %%
# substraction of numbers 
print(a-b) # substraction of two whole numbers 
print(c-d) # substraction of two real numbers
print(a-c) # substraction of one whole number and one real number
print(a-b-c) # substraction of three numbers
print(a-b-c-d) # substraction of four numbers
# Out:
# 5
# -1.5999999999999996
# 4.3
# 1.2999999999999998
# -4.0

# %% [markdown]
# #### 2.1.c) Multiplication of numbers

# %%
# multiplication of numbers 
print(a*b) # multipication of two whole numbers 
print(c*d) # multipication of two real numbers
print(a*c) # multipication of one whole number and one real number
print(a*b*c) # multipication of three numbers
print(a*b*c*d) # multipication of four numbers
# Out:
# 24
# 19.61
# 29.6
# 88.80000000000001
# 470.64000000000004

# %% [markdown]
# #### 2.1.d) Devision of numbers

# %%
# devision of numbers 
print(a/b) #  devision of two whole numbers 
print(c/d) #  devision of two real numbers
print(a/c) #  devision of one whole number and one real number
# Out:
# 2.6666666666666665
# 0.6981132075471699
# 2.162162162162162

# %%
# python also apply same rule of calculation i.e. first multiplication then devision then addition and then substraction
# here first we solve bracket then follow above rule 
result = (3+2)*(8/2)/2 # i.e. (5)*(4)/2 -> 20/2 (multiplication first) -> 10
result
# Out:
# 10.0

# %%
# if want to get remainder after devision 
print(9%2)
print(8%3)
# Out:
# 1
# 2

# %% [markdown]
# ### 2.2 Logical operators
#
# ![logical.PNG](attachment:logical.PNG)

# %%
x = 20
y = 30

x>y
# Out:
# False

# %%
x = 20
y = 30
print('Is x greater than y :- ',x>y)
print('\nIs x less than y :- ',x<y)
print('\nIs x equal to y :- ',x==y)
print('\nIs x not equal to y :- ',x!=y)
print('\nIs x greater than or equal to y :- ',x>=y)
print('\nIs x less than or equal to y :- ',x<=y)
# Out:
# Is x greater than y :-  False
#
# Is x less than y :-  True
#
# Is x equal to y :-  False
#
# Is x not equal to y :-  True
#
# Is x greater than or equal to y :-  False
#
# Is x less than or equal to y :-  True

# %%
x = True
y = False
print('Logical AND operation :- ',x and y) # True if both values are true
print('Logical OR operation :- ',x or y) # True if either of the values is true
print('NOT operation :- ',not x ) # True if operand is false
# Out:
# Logical AND operation :-  False
# Logical OR operation :-  True
# NOT operation :-  False

# %% [markdown]
# #### Assignment operator

# %%
x = 10

# %%
x = 10 + 20
x
# Out:
# 30

# %%
x+=20 # x = x+20
print ('Add 20 to x :- ',x)
# Out:
# Add 20 to x :-  30

# %%
y = 4
y
# Out:
# 4

# %%
y-=2 # 4-2 =2-2 =0
y
# Out:
# 0

# %%
# here we add number to previously existing variable having numerical value i.e we update value of left side variable 
x=10
y=5
x+=y # assignment always goes to first variable i.e x --> x = x + y
print('x: ' ,x) # x = ?
print('y: ' ,y) # y = 5
# Out:
# x:  15
# y:  5

# %%
print(x)
print(y)
# Out:
# 15
# 5

# %%
# this not an operator --> change the x-value to y-value
x =+ y
print('x: ' , x)
print('y: ' , y)
# Out:
# x:  5
# y:  5

# %% [markdown]
# ## 3. String
#
# #### It is text or words or sentence in quotation mark. It is used to store or assign categorical value to variable.

# %% [markdown]
# Strings are one of the fundamental Python data types. The term data type refers to what kind of data a value represents. Strings are used to represent text.
#
# Strings have three important properties:
# 1. Strings contain individual letters or symbols called characters.
# 2. Strings have a length, defined as the number of characters the
# string contains.
# 3. Characters in a string appear in a sequence, which means that
# each character has a numbered position in the string.

# %% [markdown]
# #### 3.1 Different ways of defining strings

# %%
type("Hello, World")
# Out:
# str

# %%
# defining string by double quotation mark 
my_name = "Shweta"
my_name
# Out:
# 'Shweta'

# %%
# type() also works for values that have been assigned to a variable:
type(my_name)
# Out:
# str

# %%
# define a sentence 
sent = "I'm going to the gym"
type(sent)
# Out:
# str

# %%
# define a paragraph 
paragraph = "This planet has—or rather had—a problem, \
which was this: most of the people living on it were unhappy for pretty much \
of the time."
type(paragraph)
# Out:
# str

# %%
# symbols in a string
string = "We're #1!, my age 77"
string
# Out:
# "We're #1!, my age 77"

# %%
# If you try to use double quotes inside a string delimited by double quotes, you’ll get an error:
text = "She said, "What time is it?" "
# Out:
#   Input In [65]
#     text = "She said, "What time is it?""
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# - If you need to include a quotation mark that matches the delimiter inside a string, then you can escape the character using a backslash:

# %%
# use escape 
text = "She said, \"What time is it?\" hi"
text
# Out:
# 'She said, "What time is it?" hi'

# %%
text = '''She said, "What time is it?" hi '''
text
# Out:
# 'She said, "What time is it?" hi '

# %%
a = 9
print(a)
type(a)
# Out:
# 9
# int

# %%
str(a)
# Out:
# '9'

# %% [markdown]
# #### 3.2 Operations on string
#
# - concatination of strings means adding two strings together

# %%
# determine length of string
string = 'abc'
len(string)
# Out:
# 3

# %%
len(text)
# Out:
# 32

# %%
# String concatenation
sent1= "My name"
sent2= " is Shweta."

sent1+sent2
# Out:
# 'My name is Shweta.'

# %%
# multiplication by integer
my_name * 2
# Out:
# 'ShwetaShweta'

# %%
# replacement of lettres
name = 'RatRR'

# %%
name.replace('R','C')
# Out:
# 'CatCC'

# %% [markdown]
# #### 3.3  indexing
#
# ![indexing.PNG](attachment:indexing.PNG)

# %% [markdown]
#  **indexing in string:**
# - forward indexing starts from zero
# - used to extract or replace element of it

# %%
my_name
# Out:
# 'Shweta'

# %%
my_name[0]
# Out:
# 'S'

# %%
my_name.index('S')
# Out:
# 0

# %%
len(my_name)
# Out:
# 6

# %%
# Last character in string
my_name[5] # n-1 -> 6-1 =5
# Out:
# 'a'

# %%
# Last character in string using len function
my_name[len(my_name)-1]
# Out:
# 'a'

# %% [markdown]
# #### Slicing

# %%
# for extracting element we should know indexing starts from 0 and end at (n-1) for string[0:n]
my_name[0:5] #n-1 -> 5-1 = 4
# Out:
# 'Shwet'

# %%
# for extracting element we should know indexing starts from 0 and end at (n-1) for string[0:n]
my_name[0:5]

# %%
# Retreive first six characters of the string
my_name[0:]
# Out:
# 'Shweta'

# %% [markdown]
# #### 3.4 Place holder : It is used in string to replace particular place by string or number by using respective type of place holder

# %%
state = "My name is "

state + "Mayur"
# Out:
# 'My name is Mayur'

# %%
my name is {10 names}

# %%
# instead of doing concatenation we use string place holder
state = "My name is %s "

state%("Mayur")
# Out:
# 'My name is Mayur '

# %%
state%("Shweta")

# %%
state = "My age is %d "
state%(27)
# Out:
# 'My age is 27 '

# %%
# we can use multiple holder at a time
state = "My name is %s and i am %d year old"
state%("Shweta",27)
# Out:
# 'My name is Shweta and i am 27 year old'

# %% [markdown]
# #### 3.5 String Functions

# %%
mystr = "   Hello Everyone "
mystr
# Out:
# '   Hello Everyone '

# %%
# Removes white space from begining & end
mystr.strip()
# Out:
# 'Hello Everyone'

# %%
mystr.lower() # Return whole string in lowercase
# Out:
# '   hello everyone '

# %%
mystr.upper() # Return whole string in uppercase
# Out:
# '   HELLO EVERYONE '

# %%
# count
mystr2 = "one two one one Three one two two three"
mystr2.count("one") # Number of times substring "one" occurred in string.
# Out:
# 4
