# %% [markdown]
# # 1. Coditional Statements

# %% [markdown]
# ## 1.1 if-else statement

# %% [markdown]
# It is used for decision making means if condition is true then execute code inside if statement otherwise execute condition inside else statement.
#
# ![if.png](attachment:if.png)

# %%
'''
if test expression(condition): (here we check whether our condition is true or not)
    print("hi") # body of if (we execute code which is inside if body if condition is true) 
'''
print("Hi") # out of if body (if condition is false then we directly jump outside if body)
# Out:
# Hi

# %%
credit_score = 700

if credit_score > 600:
    print('person is eligible for a loan')
    print('anything')
# Out:
# person is eligible for a loan
# anything

# %%
if 500 > 600:
    print('person is eligible for a loan')

# %%
if True:
    print('We are in the if body')
    print('Correct')
# Out:
# We are in the if body
# Correct

# %%
# if statement starts here
if False:
    # body starts here
    print('Incorrect')
    # body ends here 
# if statement ends here

# another snippet of code started
print('We are out of if body') 
x = 4
y = 6
x+y
# Out:
# We are out of if body
# 10

# %%
# here as 5>2 means condition is true so code under if statement get executed 
if 5>2:
    print("5 is greater than 2") # body of if
# Out:
# 5 is greater than 2

# %%
# here as 5<2 means condition is false so code under if statement not getting executed that's why we dont get any output
if (5<2):
    print("5 is less than 2")

# %%
# here expression is incorrect so code under if statement is not getting executed but code out of if body get executed 

if 2 == 3:
    print("2 is equal to 3")

print("Out of if statement")
# Out:
# Out of if statement

# %%
# here as 5<2 means condition is false so code under if statement not getting executed but under else staetment get executed
if (5<2):
    print("Correct")# body of if statement
else: 
    print("Incorrect") # body of else
# Out:
# Incorrect

# %%
# here we check whether given number is odd or even 
x = 5 

if x % 2 == 0:
    print('x is even number')
else:
    print('x is odd number')
# Out:
# x is odd number

# %%
x = input()
x = int(x)
print(type(x))
# Out:
# 4
# <class 'int'>

# %%
b=int(input())
b % 2
# Out:
# 4
# 0

# %%
#x = input()
#a= int(x)

b=int(input()) 

r = b % 2

if r != 0:
    print("Given number is odd")
else:
    print('Given number is even')
# Out:
# 6
# Given number is even

# %% [markdown]
# ## 1.2 if..elif..else statement

# %% [markdown]
# - In this case we have just one if and else statement but multiple elif statements .
# - It checks conditions one by one until true condition found.
# - If condition under if statement is false then it check conditions under elif statements and if all elif conditions are also false then it execute code under else statement.

# %%
'''
here condition under if statement is true so code under if body get executed.
i.e. we found true condition under if statement so we can run code under that statement.
and no need to proceed further means no need to check further conditions.

'''
if (1<2): #True
    print("1 is less than 2 ")
    
elif (4>2): # true
    print("4 is greater than 2")
    
else:
    print("None of the above is correct ")
# Out:
# 1 is less than 2

# %%
'''
Here condition under if statement is false but under elif statement is true.
So as we found true condition under elif statement so we can run code under that statement.
and no need to proceed further means no need to check further conditions.
 
'''
if (1>2): # false
    print("1 is less than 2 ")
    
elif (4>2): # true
    print("4 is greater than 2")
    
else:
    print("None of the above is correct ")
# Out:
# 4 is greater than 2

# %%
person = 'big data'

if person == 'python': # false
    print("eligible for a ds")
elif person == 'stats': # true
    print("eligible for a ds")
else:
    print("not eligible for a ds ")
# Out:
# not eligible for a ds

# %%
# here condition under if and elif statement are false so directly jump to else statement 
if (5<2): # false
    print("5 is less than 2 ")
elif (4<2): # false
    print("4 is less than 2")
else:
    print("None of the above is correct ")
# Out:
# None of the above is correct

# %%
# to check given number is multiple of 4 or 5 
num=int(input())

if num % 4 ==0:
    print("Given num is divisible by 4")
elif num % 5 == 0:
    print("Given num is divisible by 5")
#num % 4 != 0 and num % 5 != 0
else:
    print("Given num is not divisible by 4 and 5 ")
# Out:
# 5
# Given num is divisible by 5

# %% [markdown]
# ## 1.3 Multiple conditional statements

# %% [markdown]
# ### Conditions hold by ' and '

# %% [markdown]
# In this case, if both conditions under if statements are true then and only then code under if statement get executed .

# %%
# for ' and ' both condition must be true
if (5>3 or 5<10) and (3>4 or 6<8): 
    print("Correct")
else: 
    print("Incorrect")
# Out:
# Correct

# %%
x = 6
y = 7
# for ' and ' both condition must be true
if x < y: 
    z = x + y
    print(z)
# Out:
# 13

# %%
# here first condition is true but second is not that's why code under if statement not getting executed
if 5>3 and 5<3 : 
    print("Correct")
else:
    print("Incorrect")
# Out:
# Incorrect

# %%
# to check given number is multiple of 4 or 5 
num=int(input())

if num % 4 ==0 and num % 5 ==0:
    print("Given num is divisible by 4 and 5")
elif num % 4 == 0:
    print("Given num is divisible by 4")
elif num % 5 == 0:
    print("Given num is divisible by 5")
    
#num % 4 != 0 and num % 5 != 0
else:
    print("Given num is not divisible by 4 and 5 ")
# Out:
# 7
# Given num is not divisible by 4 and 5

# %%
vaccine=input()
vaccine = vaccine.replace('co-vaxin', 'covaxin')
vaccine
# Out:
# covaxin
# 'covaxin'

# %%
# check whether person is fully vaccinated or not
# mistakes --> .| , | : | covaxine 
# partially vaxinated conditions for all the vaxine types

vaccine=input()
vaccine = vaccine.replace(' ', '')
vaccine = vaccine.replace('co-vaxin', 'covaxin')
print('vaccine ' , vaccine)
vaccine = vaccine.lower()
num_doses=int(input())

if vaccine=='covishield' and num_doses==2:
    print('Fully vaccinated')
elif vaccine=='covaxin' and num_doses==2:
    print('Fully vaccinated')
elif vaccine=='sputnik' and num_doses==1:
    print('Fully vaccinated')
else:
    print("Not fully vaccinated")
# Out:
# covishield
# vaccine  covishield
# 2
# Fully vaccinated

# %%
# check whether given year is leap year or not
year = int(input())

if year % 4 == 0 and year % 100 != 0:
    print('Given year is a Leap year:',year)
elif year % 400 == 0:
    print('Given year is a Leap year:', year)
else:
    print('Given year is not a Leap year:',year)
# Out:
# 4
# Given year is a Leap year: 4

# %% [markdown]
# ### Conditions hold by ' or '
#
# In this case, if at least one condition under if statements is true then code will get executed.

# %%
# for or at least one condition must be true
if 5>3 or 5<1: 
    print("Correct")
else:
    print("Incorrect")
# Out:
# Correct

# %%
# here both condition are true
if 5>3 or 1<3 : 
    print("Correct")
else:
    print("Incorrect")
# Out:
# Correct

# %%
# here both condition are false
if 1>3 or 5<3 : 
    print("Correct")
else:
    print("Incorrect")
# Out:
# Incorrect

# %% [markdown]
# ## 1.4 nested if

# %%
if 5>2: #parent condition
    print("we've entered into parent body")
    if 5>3: # child condition
        print("we've entered into child body") # body of child-if
# Out:
# we've entered into parent body
# we've entered into child body

# %%
# whether person eligible or not it job or data science job
degree =str(input())
skills =str(input())

if degree=='g' or degree=="pg":
    print("qualified for IT job")
    if skills=='python' or skills=="R":
        print("qualified for data science job")
# Out:
# pg
# R
# qualified for IT job
# qualified for data science job

# %%
# if and elif --> condion <test_expression> :
# else --> condition :

if 4%2==0:
    print("4 is divisible 2")
    if 6%2==0:
        print("4 & 6 divisible by 2")
# Out:
# 4 is divisible 2
# 4 & 6 divisible by 2

# %%
# check whether person is fully vaccinated or not using combination of if-elif-else and nested if

vaccine=str(input())
num_doses=int(input())

if vaccine =='covishield':
    if num_doses==2:
        print('Fully vaccinated')
    elif num_doses==1:
        print('Partially vaccinated')
    else:
        print('Not fully vaccinated')
# Out:
# covishield
# 1
# Partially vaccinated

# %%
# check whether person is fully vaccinated or not using combination of if-elif-else and nested if

vaccine=str(input())
num_doses=int(input())

if vaccine =='covishield':
    if num_doses==2:
        print('Fully vaccinated')
    elif num_doses==1:
        print('Partially vaccinated')
    else:
        print('Not fully vaccinated')
elif vaccine =='covaxin':
    if num_doses==2:
        print('Fully vaccinated')
    else:
        print("Not fully Vaccinated")
elif vaccine =='sputnik':
    if num_doses==1:
        print('Fully vaccinated')
    else:
        print("Not fully vaccinated")
else:
    print("Not fully vaccinated")
